# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Techne.csv', sep=',')

# %%
df
# Out:
#    Issue Type  Issue key  Issue id  \
# 0       Story   DPER-892     74515
# 1       Story   DPER-905     74528
# 2       Story   DPER-935     74558
# 3       Story   DPER-960     74583
# 4       Story   DPER-962     74585
# 5       Story   DPER-963     74586
# 6       Story   DPER-992     74615
# 7       Story   DPER-993     74616
# 8       Story   DPER-995     74618
# 9       Story   DPER-996     74619
# 10      Story   DPER-998     74621
# 11      Story  DPER-1000     74623
# 12      Story  DPER-1003     74626
# 13      Story  DPER-1005     74628
# 14      Story  DPER-1014     74637
# 15      Story  DPER-1018     74641
# 16      Story  DPER-1020     74643
# 17      Story  DPER-1021     74644
# 18      Story  DPER-1032     74655
# 19      Story  DPER-1035     74658
# 20      Story  DPER-1036     74659
# 21      Story  DPER-1044     74667
# 22      Story  DPER-1054     74677
# 23      Story  DPER-1055     74678
# 24      Story  DPER-1056     74679
# ...

# %%
df2 = df.copy()
df2["Issue key"] = df2["Issue key"].apply(lambda x:int(x.split("-")[1]))

# %%
df[(df2["Issue key"] > 900) & (df2["Issue key"] < 1000)]
# Out:
#    Issue Type Issue key  Issue id  \
# 1       Story  DPER-905     74528
# 2       Story  DPER-935     74558
# 3       Story  DPER-960     74583
# 4       Story  DPER-962     74585
# 5       Story  DPER-963     74586
# 6       Story  DPER-992     74615
# 7       Story  DPER-993     74616
# 8       Story  DPER-995     74618
# 9       Story  DPER-996     74619
# 10      Story  DPER-998     74621
#
#                                               Summary
# 1   Revisão C_ERGON: PACKAGE - PCK_CONVERT_TABELAS_PA
# 2              Revisão C_ERGON: PACKAGE - PCK_RHE3413
# 3       Revisão C_ERGON: PACKAGE - RHE_ARQUIVO_DRHA01
# 4            Revisão C_ERGON: PACKAGE - RHE_INTEG_SGM
# 5   Revisão C_ERGON: PACKAGE - RHE_PACK_ACESSO_USU...
# 6   Revisão C_ERGON: PACKAGE - RHE_PCK_ARQUIVOS_TX...
# 7   Revisão C_ERGON: PACKAGE - RHE_PCK_ATO_APOSENT...
# 8              Revisão C_ERGON: PACKAGE - RHE_PCK_AUX
# 9     Revisão C_ERGON: PACKAGE - RHE_PCK_AUX_EMPRESAS
# ...

# %%
df3 = pd.read_html("https://www.superanimes.site")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-2014f1f42f39> in <module>()
# ----> 1 df3 = pd.read_html("https://www.superanimes.site")
#
# c:\users\ian.leocadio\appdata\local\programs\python\python36-32\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na)
#     913                   thousands=thousands, attrs=attrs, encoding=encoding,
#     914                   decimal=decimal, converters=converters, na_values=na_values,
# --> 915                   keep_default_na=keep_default_na)
#
# c:\users\ian.leocadio\appdata\local\programs\python\python36-32\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, **kwargs)
#     747             break
#     748     else:
# ...
